# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# Imports

import requests  
import pandas as pd 

import os

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# Generate token with a POST request

client_id = 'ef7c6b0baa21426b99a8fc4d020cce3d'       # CLIENT ID >> Se colocan como strings
client_secret = '32b323294d8e4585951724569dd315ef'   # CLIENT SECRET >> Borrarlo cuando se haga push + Kernel Clean Output
auth_url = 'https://accounts.spotify.com/api/token'  # Para conseguir una contraseña temporal

# %% [markdown]
# # Generate token with a POST request

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
auth_response    # Comprobar qué ha construido
# Out:
# {'access_token': 'BQAioJlQEM0_yGb0kbSDw9HIehdAUjVdpUd7r5decuogbZJ3icj0KHllI8XVrEWhhTt0cYIJF4wPxd2qc-Ohw6KD2OaQkP9Ys8oUbtcYTby96rbsJOI',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
access_token = auth_response['access_token']   # Guardo el token del diccionario
access_token
# Out:
# 'BQAioJlQEM0_yGb0kbSDw9HIehdAUjVdpUd7r5decuogbZJ3icj0KHllI8XVrEWhhTt0cYIJF4wPxd2qc-Ohw6KD2OaQkP9Ys8oUbtcYTby96rbsJOI'

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_uri` (i.e.: end-point), parameters and `headers` for your __GET__ operations

# %%
# Base end-point construction

base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'

header_info = {'Authorization': 'Bearer {token}'.format(token=access_token)}  # Necesitas este header para indicarle 
                                                                              # cuál es tu token para conectarte a la api

# %%
header_info        # Comprobar qué ha construido
# Out:
# {'Authorization': 'Bearer BQAioJlQEM0_yGb0kbSDw9HIehdAUjVdpUd7r5decuogbZJ3icj0KHllI8XVrEWhhTt0cYIJF4wPxd2qc-Ohw6KD2OaQkP9Ys8oUbtcYTby96rbsJOI'}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need.
#
# __Here you have the different artists to start with:__
#
# - __Option 1:__ 0L8ExT028jH3ddEcZwqJJ5
#
# - __Option 2:__ 4Y7tXHSEejGu1vQ9bwDdXW
#
# - __Option 3:__ 6FBDaR13swtiWwGhX1WQsP
#
# - __Option 4:__ 0kyQwKHCZnKE7kTXkxXjrB
#
# - __Option 5:__ 2d0hyoQ5ynDBnkvAbJKORj
#
# - __Option 6:__ 3bgsNtcf5d5h9jbQbohfBK
#
# - __Option 7:__ 7mWCSSOYqm4E9mB7V4ot6S
#
# - __Option 8:__ 64KEffDW9EtZ1y2vBYgq8T
#
# - __Option 9:__ 4k1ELeJKT1ISyDv8JivPpB
#
# - __Option 10:__ 4Z8W4fKeB5YxbusRsdQVPb
#
# - __Option 11:__ 26dSoYclwsYLMAKD3tpOr4
#
# - __Option 12:__ 7y97mc3bZRFXzT2szRM4L4
#
# - __Option 13:__ 1w5Kfo2jwwIPruYS2UWh56
#
#
# > Remember to check the [Requests](https://requests.readthedocs.io/en/latest/) library docs!!!
#
# ---

# %% [markdown]
# # Código bien
# ## Mi artista principal será Rosalía
# 1. Extraer artistas relacionados de Rosalía
# 2. Extraer el top de canciones de esos artistas relacionados
#
# Bonus track: Descubrir si su ex Rauw Alejandro está entre los artistas relacionados por el salseo

# %%
# Paso 1. Extraer el endpoint de Rosalía. 

artist_id = '7ltDVBr6mKbRvohxheJ9h1'

method = '/related-artists'

rosalia_endpoint = base_url + resource + artist_id + method
rosalia_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1/related-artists'

# %%
# Llamamos a la API y pasamos a .json()

related_artist_json = requests.get(rosalia_endpoint, headers = header_info).json()

# %%
related_artist_json.keys()
# Out:
# dict_keys(['artists'])

# %%
related_artist_json['artists']   # Aquí comienzas a ver en el chorro a artistas relacionadas Bad Gyal o Nathy Peluso
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3VHAySZQPlfGlNLslzXYpN'},
#   'followers': {'href': None, 'total': 1094153},
#   'genres': ['r&b en espanol', 'rap latina'],
#   'href': 'https://api.spotify.com/v1/artists/3VHAySZQPlfGlNLslzXYpN',
#   'id': '3VHAySZQPlfGlNLslzXYpN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb04b18dbf14d3d5e7c7da20bc',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517404b18dbf14d3d5e7c7da20bc',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17804b18dbf14d3d5e7c7da20bc',
#     'width': 160}],
#   'name': 'NATHY PELUSO',
#   'popularity': 63,
#   'type': 'artist',
#   'uri': 'spotify:artist:3VHAySZQPlfGlNLslzXYpN'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4F4pp8NUW08JuXwnoxglpN'},
#   'followers': {'href': None, 'total': 1203858},
#   'genres': ['neoperreo',
#    'rap catala',
# ...

# %%
len(related_artist_json['artists'])   # Tiene 20 artistas relacionados
# Out:
# 20

# %%
related_artist_json['artists'][0].keys()   # Accedes a la primera llave para ver qué tiene
# Out:
# dict_keys(['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri'])

# %%
# Meto en un dataframe las keys que me interesen del anterior. 

df_rel_artist = pd.DataFrame(related_artist_json['artists'])[['name', 'id', 'genres', 'followers', 'uri']]

# %%
df_rel_artist   # Aprobado el bonus. Rauw Alejandro es el 7º artista relacionado.
# Out:
#               name                      id  \
# 0     NATHY PELUSO  3VHAySZQPlfGlNLslzXYpN
# 1         Bad Gyal  4F4pp8NUW08JuXwnoxglpN
# 2      Lola Indigo  3bvfu2KAve4lPHrhEFDZna
# 3       C. Tangana  5TYxZTjIPqKM8K8NuP9woO
# 4           Aitana  7eLcDZDYHXZCebtQmVFL25
# 5          Becky G  4obzFoKoKRHIphyHzJ35G3
# 6      Paloma Mami  7rOlQwf8OuFLFQp4aydjBt
# 7   Rauw Alejandro  1mcTU81TzQhprhouKaTkpq
# 8    NATTI NATASHA  1GDbiv3spRmZ1XdM1jQbT7
# 9         Ana Mena  6k8mwkKJKKjBILo7ypBspl
# 10  Mala Rodríguez  3Ces1OJeGOVGcUB0wPaPXJ
# 11        Tokischa  2p4aN0Uxkk3iT3HK0cJ2cJ
# 12         Quevedo  52iwsT98xCoGgiGntTiR7K
# 13       Lele Pons  6i3DxIlAqnDkwELLw4aVrx
# 14         KAROL G  790FomKkXshlbRYZFtlgla
# 15            TINI  7vXDAI8JwjW531ouMGbfcp
# 16        J Balvin  1vyhD5VmyZ7KMfW5gqLgo5
# 17    Nicki Nicole  2UZIAOlrnyZmyzt1nuXr9y
# 18   Manuel Turizo  0tmwSHipWxN12fsoLcFU3B
# 19      Young Miko  3qsKSpcV3ncke3hw52JSMB
#
# ...

# %%
# Aplicas una lambda con apply para que la columna de followers solo aparezca el total 
df_rel_artist['followers'] = df_rel_artist['followers'].apply(lambda row: row['total'])

# %%
df_rel_artist
# Out:
#               name                      id  \
# 0     NATHY PELUSO  3VHAySZQPlfGlNLslzXYpN
# 1         Bad Gyal  4F4pp8NUW08JuXwnoxglpN
# 2      Lola Indigo  3bvfu2KAve4lPHrhEFDZna
# 3       C. Tangana  5TYxZTjIPqKM8K8NuP9woO
# 4           Aitana  7eLcDZDYHXZCebtQmVFL25
# 5          Becky G  4obzFoKoKRHIphyHzJ35G3
# 6      Paloma Mami  7rOlQwf8OuFLFQp4aydjBt
# 7   Rauw Alejandro  1mcTU81TzQhprhouKaTkpq
# 8    NATTI NATASHA  1GDbiv3spRmZ1XdM1jQbT7
# 9         Ana Mena  6k8mwkKJKKjBILo7ypBspl
# 10  Mala Rodríguez  3Ces1OJeGOVGcUB0wPaPXJ
# 11        Tokischa  2p4aN0Uxkk3iT3HK0cJ2cJ
# 12         Quevedo  52iwsT98xCoGgiGntTiR7K
# 13       Lele Pons  6i3DxIlAqnDkwELLw4aVrx
# 14         KAROL G  790FomKkXshlbRYZFtlgla
# 15            TINI  7vXDAI8JwjW531ouMGbfcp
# 16        J Balvin  1vyhD5VmyZ7KMfW5gqLgo5
# 17    Nicki Nicole  2UZIAOlrnyZmyzt1nuXr9y
# 18   Manuel Turizo  0tmwSHipWxN12fsoLcFU3B
# 19      Young Miko  3qsKSpcV3ncke3hw52JSMB
#
# ...

# %% [markdown]
# # Paso 1 conseguido: tengo los 20 artistas relacionados de Rosalía

# %% [markdown]
# # Paso 2: extraer las top tracks de cada uno de los artistas relacionados de Rosalía

# %%
# Paso 1. Extraer el endpoint de top-tracks. 

artist_id = '4F4pp8NUW08JuXwnoxglpN'  # Pillo el ID de Bad Gyal

method = '/top-tracks'

argument = '?market=ES'

full_endpoint = base_url + resource + artist_id + method + argument
full_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/4F4pp8NUW08JuXwnoxglpN/top-tracks?market=ES'

# %%
top_tracks_json = requests.get(full_endpoint, headers = header_info).json()   # Llamamos a la api y metemos en json

# %%
top_tracks_json.keys()   # Solo una key: tracks
# Out:
# dict_keys(['tracks'])

# %%
top_tracks_json['tracks']
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4F4pp8NUW08JuXwnoxglpN'},
#      'href': 'https://api.spotify.com/v1/artists/4F4pp8NUW08JuXwnoxglpN',
#      'id': '4F4pp8NUW08JuXwnoxglpN',
#      'name': 'Bad Gyal',
#      'type': 'artist',
#      'uri': 'spotify:artist:4F4pp8NUW08JuXwnoxglpN'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2p4aN0Uxkk3iT3HK0cJ2cJ'},
#      'href': 'https://api.spotify.com/v1/artists/2p4aN0Uxkk3iT3HK0cJ2cJ',
#      'id': '2p4aN0Uxkk3iT3HK0cJ2cJ',
#      'name': 'Tokischa',
#      'type': 'artist',
#      'uri': 'spotify:artist:2p4aN0Uxkk3iT3HK0cJ2cJ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qsKSpcV3ncke3hw52JSMB'},
#      'href': 'https://api.spotify.com/v1/artists/3qsKSpcV3ncke3hw52JSMB',
#      'id': '3qsKSpcV3ncke3hw52JSMB',
#      'name': 'Young Miko',
#      'type': 'artist',
# ...

# %%
len(top_tracks_json['tracks'])  # 10 canciones
# Out:
# 10

# %%
top_tracks_json['tracks'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
df_bad_gyal = pd.DataFrame(top_tracks_json['tracks'])[['name', 'id', 'album', 'uri']]

# %%
df_bad_gyal   # DF de ejempplo
# Out:
#                          name                      id  \
# 0                  Chulo pt.2  0J9g1MMJDhyvOb3NWckHMm
# 1                     KÁRMIKA  3mFNc5EQn30irR983Wg9OD
# 2                       Chulo  3szqC0lxrJdhn3eW6FfFfo
# 3  Fiebre (Prod. King DouDou)  5xtxxuIqInrLDSfjA6Co3o
# 4             GHETTO PRINCESS  6GgpoeDugrrXl06NIsE1Bo
# 5                     Mi Lova  6qUfKsUPGERMdhOwPIqhsS
# 6                   Blin Blin  4OWPAMZcoRwAmMA971KBTh
# 7           Flow 2000 - Remix  7fRtruULHGuwC0wNRx1HSa
# 8                   La Prendo  6t48UVZvQWh5wWfWlCZfzY
# 9                      Real G  6WU2eYUtOL91iROonROPyh
#
#                                                album  \
# 0  {'album_type': 'single', 'artists': [{'externa...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'single', 'artists': [{'externa...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'single', 'artists': [{'externa...
# ...

# %%
# Problema inesperado. La columna album es caca

# %%
type(df_bad_gyal['album'])
len(df_bad_gyal['album'])
# Out:
# 10

# %%
df_bad_gyal['album'][0].keys()  # Veo el nombre y decido que solo quiero el name del album
# Out:
# dict_keys(['album_type', 'artists', 'external_urls', 'href', 'id', 'images', 'is_playable', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
df_bad_gyal['album'] = df_bad_gyal['album'].apply(lambda row: row['name'])  

# En realidad funciona pero como son artistas modernos que solo sacan una canción, el nombre del album en muchas ocasiones
# se llama igual.

# %%
df_bad_gyal
# Out:
#                          name                      id               album  \
# 0                  Chulo pt.2  0J9g1MMJDhyvOb3NWckHMm          Chulo pt.2
# 1                     KÁRMIKA  3mFNc5EQn30irR983Wg9OD  MAÑANA SERÁ BONITO
# 2                       Chulo  3szqC0lxrJdhn3eW6FfFfo               Chulo
# 3  Fiebre (Prod. King DouDou)  5xtxxuIqInrLDSfjA6Co3o   Slow Wine Mixtape
# 4             GHETTO PRINCESS  6GgpoeDugrrXl06NIsE1Bo     GHETTO PRINCESS
# 5                     Mi Lova  6qUfKsUPGERMdhOwPIqhsS             Mi Lova
# 6                   Blin Blin  4OWPAMZcoRwAmMA971KBTh             Warm Up
# 7           Flow 2000 - Remix  7fRtruULHGuwC0wNRx1HSa   Flow 2000 (Remix)
# 8                   La Prendo  6t48UVZvQWh5wWfWlCZfzY           La Prendo
# 9                      Real G  6WU2eYUtOL91iROonROPyh              Real G
#
#                                     uri
# 0  spotify:track:0J9g1MMJDhyvOb3NWckHMm
# 1  spotify:track:3mFNc5EQn30irR983Wg9OD
# ...

# %% [markdown]
# # Okey, ¿y ahora?

# %% [markdown]
# ## Tengo un df de los artistas relacionados de Rosalía
# ## Y un df del top track de Bad Gyal
#
# Next Step: crear una función que los df de artistas relacionados de Rosalía.

# %%
def get_top_artist(id_artist):
    resource = 'artists/'
    artist_id = id_artist
    method = '/top-tracks'
    argument = '?market=ES'
    
    full_endpoint = base_url + resource + artist_id + method + argument
    
    top_tracks_json = requests.get(full_endpoint, headers = header_info).json()
    df_tracks = pd.DataFrame(top_tracks_json['tracks'])[['name', 'id', 'album', 'artists', 'uri']]
    
    df_tracks['related_id'] = id_artist       # include in df selected id artis
    
    #df_def = pd.concat([df_tracks], axis=0)
    
    return df_tracks

# %% [markdown]
# ## Extraer cada id artist del df_rel_artist

# %%
lista_artistas = []

for id in df_rel_artist['id']:
    lista_artistas.append(id)

# %%
lista_artistas            # Ahora tengo todos los id en una lista
# Out:
# ['3VHAySZQPlfGlNLslzXYpN',
#  '4F4pp8NUW08JuXwnoxglpN',
#  '3bvfu2KAve4lPHrhEFDZna',
#  '5TYxZTjIPqKM8K8NuP9woO',
#  '7eLcDZDYHXZCebtQmVFL25',
#  '4obzFoKoKRHIphyHzJ35G3',
#  '7rOlQwf8OuFLFQp4aydjBt',
#  '1mcTU81TzQhprhouKaTkpq',
#  '1GDbiv3spRmZ1XdM1jQbT7',
#  '6k8mwkKJKKjBILo7ypBspl',
#  '3Ces1OJeGOVGcUB0wPaPXJ',
#  '2p4aN0Uxkk3iT3HK0cJ2cJ',
#  '52iwsT98xCoGgiGntTiR7K',
#  '6i3DxIlAqnDkwELLw4aVrx',
#  '790FomKkXshlbRYZFtlgla',
#  '7vXDAI8JwjW531ouMGbfcp',
#  '1vyhD5VmyZ7KMfW5gqLgo5',
#  '2UZIAOlrnyZmyzt1nuXr9y',
#  '0tmwSHipWxN12fsoLcFU3B',
#  '3qsKSpcV3ncke3hw52JSMB']

# %%
# Extraer del df_bad_gyal la info de 'artist', 'cancion', 'id_cancion'

# %%
def get_top_artist(id_artist):
    resource = 'artists/'
    artist_id = id_artist
    method = '/top-tracks'
    argument = '?market=ES'
    
    full_endpoint = base_url + resource + artist_id + method + argument
    
    response = requests.get(full_endpoint, headers = header_info).json()
    df_tracks = pd.DataFrame(top_tracks_json['tracks'])[['id', 'href','name','uri']]
    
    df_tracks['related_id'] = id_artist       # include in df selected id artis
    
    # Guardar cada df en la carpeta data 
    df_tracks.to_csv('../data/' + input('artista : ') + '.csv')   # Ahora sí lo exporta a .csv
    
    return df_tracks

# %%
for artist in lista_artistas: 
    get_top_artist(artist)     # Voy poniendo a mano el nombre del artista correspondiente para localizarlo en el csv.
# Out:
# artista : nathy_peluso
# artista : bad_gyal
# artista : lola_indigo
# artista : c_tangana
# artista : aitana
# artista : becky_g
# artista : paloma_mami
# artista : rauw_alejandro
# artista : natti_natasha
# artista : ana_mena
# artista : mala_rodriguez
# artista : tokischa
# artista : quevedo
# artista : lele_pons
# artista : karol_g
# artista : tini
# artista : j_balvin
# artista : nicki_nicole
# artista : manuel_turizo
# artista : young_miko

# %%
# referencia: https://es.stackoverflow.com/questions/570245/c%C3%B3mo-leer-varios-archivos-csv-en-diferentes-directorios-en-un-solo-dataframe 

dfs = []
nombre_carpeta = '../data/'
contenido = os.listdir(nombre_carpeta)

for archivo in contenido:
    if archivo.endswith('.csv'): 
        ruta_completa = os.path.join(nombre_carpeta, archivo)
        df = pd.read_csv(ruta_completa)
        dfs.append(df)

#print(dfs)    
macro_df = pd.concat(dfs, ignore_index=True)   # ignore_index=True para que ignore los index individuales 

macro_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   id          200 non-null    object
#  2   href        200 non-null    object
#  3   name        200 non-null    object
#  4   uri         200 non-null    object
#  5   related_id  200 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 9.5+ KB

# %%
macro_df    # Este es el dataframe final
# Out:
#      Unnamed: 0                      id  \
# 0             0  0J9g1MMJDhyvOb3NWckHMm
# 1             1  3mFNc5EQn30irR983Wg9OD
# 2             2  3szqC0lxrJdhn3eW6FfFfo
# 3             3  5xtxxuIqInrLDSfjA6Co3o
# 4             4  6GgpoeDugrrXl06NIsE1Bo
# ..          ...                     ...
# 195           5  6qUfKsUPGERMdhOwPIqhsS
# 196           6  4OWPAMZcoRwAmMA971KBTh
# 197           7  7fRtruULHGuwC0wNRx1HSa
# 198           8  6t48UVZvQWh5wWfWlCZfzY
# 199           9  6WU2eYUtOL91iROonROPyh
#
#                                                   href  \
# 0    https://api.spotify.com/v1/tracks/0J9g1MMJDhyv...
# 1    https://api.spotify.com/v1/tracks/3mFNc5EQn30i...
# 2    https://api.spotify.com/v1/tracks/3szqC0lxrJdh...
# 3    https://api.spotify.com/v1/tracks/5xtxxuIqInrL...
# 4    https://api.spotify.com/v1/tracks/6GgpoeDugrrX...
# ..                                                 ...
# 195  https://api.spotify.com/v1/tracks/6qUfKsUPGERM...
# ...

# %% [markdown]
# # Pruebas clase

# %% [markdown]
# ## Extraer segundo endpoint de top tracks

# %%
artist_id = '7mWCSSOYqm4E9mB7V4ot6S'

method = '/top-tracks'

argument = '?market=ES'

full_endpoint = base_url + resource + artist_id + method + argument
full_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/7mWCSSOYqm4E9mB7V4ot6S/top-tracks?market=ES'

# %%
top_tracks_response = requests.get(full_endpoint, headers = header_info)   # Lllamamos a la api de spotify
top_tracks_response.status_code
# Out:
# 200

# %%
# Explorar el objeto responde
top_tracks_response.hearders
top_tracks_response.content
top_tracks_response.requests 
top_tracks_response.text
top_tracks_response.url
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Explorar el objeto responde
# ----> 2 top_tracks_response.hearders
#       3 top_tracks_response.content
#       4 top_tracks_response.requests
#
# AttributeError: 'Response' object has no attribute 'hearders'

# %%
# Convertirnos el objeto response en un json
top_tracks_json = top_tracks_response.json()   
top_tracks_json
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1Tz1WfJZkvWPhyFHWAzZLo'},
#     'href': 'https://api.spotify.com/v1/albums/1Tz1WfJZkvWPhyFHWAzZLo',
#     'id': '1Tz1WfJZkvWPhyFHWAzZLo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734e19f670ace532c6c2202094',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024e19f670ace532c6c2202094',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514e19f670ace532c6c2202094',
#       'width': 64}],
# ...

# %%
top_tracks_json.keys()
# Out:
# dict_keys(['tracks'])

# %%
len(top_tracks_json['tracks'])
# Out:
# 10

# %%
top_tracks_json['tracks'][0].keys()         # Accedes a la primera clave
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Vamos a construit el df con las canciones

# %%
df_tracks = pd.DataFrame(top_tracks_json['tracks'])[['id', 'href','name','uri']] # Coges solo las keys que quieras

# %%
df_tracks
# Out:
#                        id                                               href  \
# 0  0tzixmHNQfE6S6SirSToxW  https://api.spotify.com/v1/tracks/0tzixmHNQfE6...
# 1  7kyLtcgYgQPrXkxtAb72iY  https://api.spotify.com/v1/tracks/7kyLtcgYgQPr...
# 2  1YFBO31kSEYo1DVkjSj8LG  https://api.spotify.com/v1/tracks/1YFBO31kSEYo...
# 3  0HmQkmfYXRPweIg1ycw1R8  https://api.spotify.com/v1/tracks/0HmQkmfYXRPw...
# 4  24yTPZXispM0aKaUHxLONo  https://api.spotify.com/v1/tracks/24yTPZXispM0...
# 5  4nUGdDdFaBS6SYBOgtVIVr  https://api.spotify.com/v1/tracks/4nUGdDdFaBS6...
# 6  1ORb6uGvpjsFwZK8FUpzWy  https://api.spotify.com/v1/tracks/1ORb6uGvpjsF...
# 7  3Pr70knS8uTSiKbwf4rGav  https://api.spotify.com/v1/tracks/3Pr70knS8uTS...
# 8  1SHwaYmCN3v6qgpFidqZ1S  https://api.spotify.com/v1/tracks/1SHwaYmCN3v6...
# 9  0rX7mbNXYmAolFCY2TYVPH  https://api.spotify.com/v1/tracks/0rX7mbNXYmAo...
#
#                                         name  \
# 0  El Ultimo Adiós - Varios Artistas Version
# ...

# %%
# Hacer una función para conseguir el top-tracks de un id_artist

# %%
def get_top_artist(id_artist):
    resource = 'artists/'
    artist_id = id_artist
    method = '/top-tracks'
    argument = '?market=ES'
    
    full_endpoint = base_url + resource + artist_id + method + argument
    
    response = requests.get(full_endpoint, headers = header_info).json()
    df_tracks = pd.DataFrame(top_tracks_json['tracks'])[['id', 'href','name','uri']]
    
    df_tracks['related_id'] = id_artist       # include in df selected id artis
    
    return df_tracks

# %%
get_top_artist('0L8ExT028jH3ddEcZwqJJ5')
# Out:
#                        id                                               href  \
# 0  0tzixmHNQfE6S6SirSToxW  https://api.spotify.com/v1/tracks/0tzixmHNQfE6...
# 1  7kyLtcgYgQPrXkxtAb72iY  https://api.spotify.com/v1/tracks/7kyLtcgYgQPr...
# 2  1YFBO31kSEYo1DVkjSj8LG  https://api.spotify.com/v1/tracks/1YFBO31kSEYo...
# 3  0HmQkmfYXRPweIg1ycw1R8  https://api.spotify.com/v1/tracks/0HmQkmfYXRPw...
# 4  24yTPZXispM0aKaUHxLONo  https://api.spotify.com/v1/tracks/24yTPZXispM0...
# 5  4nUGdDdFaBS6SYBOgtVIVr  https://api.spotify.com/v1/tracks/4nUGdDdFaBS6...
# 6  1ORb6uGvpjsFwZK8FUpzWy  https://api.spotify.com/v1/tracks/1ORb6uGvpjsF...
# 7  3Pr70knS8uTSiKbwf4rGav  https://api.spotify.com/v1/tracks/3Pr70knS8uTS...
# 8  1SHwaYmCN3v6qgpFidqZ1S  https://api.spotify.com/v1/tracks/1SHwaYmCN3v6...
# 9  0rX7mbNXYmAolFCY2TYVPH  https://api.spotify.com/v1/tracks/0rX7mbNXYmAo...
#
#                                         name  \
# 0  El Ultimo Adiós - Varios Artistas Version
# ...

# %% [markdown]
# # Qué hacer:
# 1. Traer todos los related-artists de un artista
# 2. Traer todos los top-tracks de los related-artist del artista de inicio
# 3. Meterlo en un dataframe
#
# - Objetivo: sacar una lista de artistas

# %%
# Elegir un artista y sacar su información con get artist
# Documentación: https://developer.spotify.com/documentation/web-api/reference/get-an-artist

# %%
id_selected = '4k1ELeJKT1ISyDv8JivPpB'

resource = 'artists'
parameters = f'/{id_selected}'

url = base_url + resource + parameters
print(url)
# Out:
# https://api.spotify.com/v1/artists/4k1ELeJKT1ISyDv8JivPpB

# %%
response = requests.get(url, headers = header_info).json()

# %%
response
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4k1ELeJKT1ISyDv8JivPpB'},
#  'followers': {'href': None, 'total': 2343687},
#  'genres': ['big beat', 'breakbeat', 'dance rock', 'hardcore techno', 'rave'],
#  'href': 'https://api.spotify.com/v1/artists/4k1ELeJKT1ISyDv8JivPpB',
#  'id': '4k1ELeJKT1ISyDv8JivPpB',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb147841812056c247407811f3',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174147841812056c247407811f3',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178147841812056c247407811f3',
#    'width': 160}],
#  'name': 'The Prodigy',
#  'popularity': 62,
#  'type': 'artist',
#  'uri': 'spotify:artist:4k1ELeJKT1ISyDv8JivPpB'}

# %%
dict_artist = dict((key, [response[key]]) for key in ['id', 'name', 'genre', 'popularity', 'followers'] if key in response)

# %%
df_artist = pd.DataFrame(dict_artist)

# %%
df_artist
# Out:
#                        id         name  popularity  \
# 0  4k1ELeJKT1ISyDv8JivPpB  The Prodigy          62
#
#                           followers
# 0  {'href': None, 'total': 2343687}

# %%
# rename columns
df_artist = df_artist.rename(columns={'id': 'artist_id',
                                     'name': 'artist_name',
                                     'genres': 'artist_genres',
                                     'popularity': 'artist_popularity',
                                     'followers': 'artist_followers'})

df_artist
# Out:
#                 artist_id  artist_name  artist_popularity  \
# 0  4k1ELeJKT1ISyDv8JivPpB  The Prodigy                 62
#
#                    artist_followers
# 0  {'href': None, 'total': 2343687}

# %%
df_artist['artist_total_followers'] = df_artist['artist_followers'].apply(lambda row: row['total'])
# Pasa una lamba por artist_followers, indicándole que solo quieres la row 'Total' dentro de 'artist_follers'
# y eso lo mete en un 'artists_total_followers

# %%
df_artist
# Out:
#                 artist_id  artist_name  artist_popularity  \
# 0  4k1ELeJKT1ISyDv8JivPpB  The Prodigy                 62
#
#                    artist_followers  artist_total_followers
# 0  {'href': None, 'total': 2343687}                 2343687

# %%
# drop dirty column porque ahora tienes dos columnas y una que es inservible, artist_followers

# %%
df_artist.drop("artist_followers", axis=1, inplace=True)   # Te cargas la columna artist_followers

# %%
df_artist
# Out:
#                 artist_id  artist_name  artist_popularity  \
# 0  4k1ELeJKT1ISyDv8JivPpB  The Prodigy                 62
#
#    artist_total_followers
# 0                 2343687

# %% [markdown]
# ## Coges artistas relacionados con el nuestro

# %%
id_selected = '4k1ELeJKT1ISyDv8JivPpB'
parameters = f'{id_selected}/related-artists'
artist = 'artists/'
url = base_url + artist + parameters
print(url)
# Out:
# https://api.spotify.com/v1/artists/4k1ELeJKT1ISyDv8JivPpB/related-artists

# %%
# API call
response = requests.get(url, headers = header_info).json()

# %%
response
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Y7tXHSEejGu1vQ9bwDdXW'},
#    'followers': {'href': None, 'total': 1166499},
#    'genres': ['big beat', 'electronica'],
#    'href': 'https://api.spotify.com/v1/artists/4Y7tXHSEejGu1vQ9bwDdXW',
#    'id': '4Y7tXHSEejGu1vQ9bwDdXW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5ebbbb4a8ed961af5b1989e2b6a',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab67616100005174bbb4a8ed961af5b1989e2b6a',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f178bbb4a8ed961af5b1989e2b6a',
#      'width': 160}],
#    'name': 'Fatboy Slim',
#    'popularity': 61,
#    'type': 'artist',
#    'uri': 'spotify:artist:4Y7tXHSEejGu1vQ9bwDdXW'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1GhPHrq36VKCY3ucVaZCfo'},
#    'followers': {'href': None, 'total': 1977593},
# ...

# %%
df_related_artist = pd.DataFrame(response['artists'])[['id', 'name', 'genres', 'popularity', 'followers']]

# %%
df_related_artist
# Out:
#                         id                   name  \
# 0   4Y7tXHSEejGu1vQ9bwDdXW            Fatboy Slim
# 1   1GhPHrq36VKCY3ucVaZCfo  The Chemical Brothers
# 2   5T4UKHhr4HGIC0VzdZQtAE              Faithless
# 3   4YrKBkKSVeqDamzBPWVnSJ          Basement Jaxx
# 4   1PXHzxRDiLnjqNrRn2Xbsa             Underworld
# 5   5eKLa1xyHLq8ERWmT1CRHj     The Crystal Method
# 6   7MqnCTCAX6SsIYYdJCQj9B               Pendulum
# 7   37f9cjf8Ic4t7vYNRYAzI7             Apollo 440
# 8   3csPCeXsj2wezyvkRFzvmV                Orbital
# 9   6FXMGgJwohJLUSr5nVlf9X         Massive Attack
# 10  67tgMwUfnmqzYsNAtnP6YJ          Groove Armada
# 11  72hqBMsw7x5jnfxxwkii8L              Leftfield
# 12  3Z7thZHrtFvqp8OpPffPKp         Propellerheads
# 13  3OsRAKCvk37zwYcnzRf5XF                   Moby
# 14  6liAMWkVf5LH7YR9yfFy1Y             Portishead
# 15  3jNkaOXasoc7RsxdchvEVq         Chase & Status
# 16  11wRdbnoYqRddKBrpHt4Ue               Kasabian
# 17  2nszamLjZFgu3Yx77mKxuC                  UNKLE
# ...

# %%
# rename columns

# add a columns with selected id artist

# join artist and related artist to merge info

# %% [markdown]
# ---
#
# ### Bonus track!!!
#
# You can publish your own Playlist with [`/playlists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/create-playlist) and [`/tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/add-tracks-to-playlist).
#
# ![I quit](https://media.giphy.com/media/gui67fZ3xIneM/giphy.gif)

# %% [markdown]
# ## Create a Playlist

# %%
# Create endpoint
user_id = 'mteresa92'

resource = 'users'
parameters = f'/{user_id}/playlist'

url = base_url + resource + parameters
print(url)
# Out:
# https://api.spotify.com/v1/users/mteresa92/playlist

# %%
response_playlist = requests.get(url, headers = header_info)

# %%
response_playlist.status_code
# Out:
# 404

# %%
# Doble autentificación >> Sacar el error 403

# %%
# Bonus

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)

# %% [markdown]
# ---
